# %%
import numpy as np
import pandas as pd

# %%
A=pd.read_csv(r'C:\Users\Lenovo\Desktop\mldatasets\Mall_Customers.csv')

# %% [markdown]
# # 1. To take variable in x

# %%
X=A.iloc[:,3:]
# X=A.iloc[:,[3,4]].values

# %%
X

# A.head()
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 0                    15                      39
# 1                    15                      81
# 2                    16                       6
# 3                    16                      77
# 4                    17                      40
# ..                  ...                     ...
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83
#
# [200 rows x 2 columns]

# %% [markdown]
# # 2. For finding value of k using elbow method

# %%
from sklearn.cluster import KMeans

# %%
    sse = []
    for k in range(1,16):
        kmeans = KMeans(n_clusters=k) #Creating objects for k values
        kmeans.fit(X) #For fitting value of x
        sse.append(kmeans.inertia_) #All inertia value of k(1-15) append in sse

# %%
sse
# Out:
# [269981.28,
#  181363.59595959593,
#  106348.37306211118,
#  73679.78903948836,
#  44448.45544793371,
#  37233.81451071001,
#  30227.606513152015,
#  25039.434641445514,
#  22852.120979986197,
#  19669.301557148294,
#  17873.825418046006,
#  15817.245013841313,
#  14265.263882522704,
#  12746.969092182328,
#  11733.84024944354]

# %% [markdown]
# # 3. To check elbow point

# %%
import matplotlib.pyplot as plt

# %%
plt.title('kmeans custers')   
plt.xlabel('Number of clusters')  
plt.ylabel('wcss')  
plt.plot(range(1,16), sse) #Give k value from(1-15) and inertia value according to k (sse)

# %% [markdown]
# # 4. To give lable for each clusters

# %%
km = KMeans(n_clusters=5,random_state=0)
km=kmeans.fit_predict(X)

# %%
km
# Out:
# array([ 4,  2,  7,  2,  4,  2,  7, 14,  7,  2,  7, 14,  7,  2,  7,  2,  4,
#         2,  4, 14,  4,  2,  7,  2,  7,  2,  4,  2,  4, 14,  7,  2,  7, 14,
#         7,  2,  7,  2,  4,  2,  4, 14,  4,  6,  4,  6,  6,  6,  6,  6,  6,
#         6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,
#         6,  6,  6,  6,  6,  6, 11, 11, 11, 11, 11,  0, 11, 11,  0, 11, 11,
#        11, 11, 11, 11, 11, 11,  0, 11,  0,  0, 11, 11, 11,  0, 11,  0, 11,
#        11, 11, 11,  0, 11,  0,  0, 11, 11, 11,  0,  0, 11, 11,  0, 11,  0,
#        11, 11,  0, 11, 12,  0,  1,  0, 12, 10,  1, 10,  1,  0,  1, 10, 12,
#        10,  1, 10,  1, 10, 12,  0, 12, 10, 12,  0,  1,  3, 12,  3, 12,  3,
#         1,  3, 12, 10,  1, 10,  1,  0, 12, 10, 12,  3,  1,  3, 12,  3,  1,
#         3,  1,  3, 12,  3, 12,  3,  1,  3,  5, 13,  5, 13,  5, 13,  5, 13,
#         5, 13,  5, 13,  5,  9,  5,  9,  8,  9,  8,  9,  8])

# %% [markdown]
# # 5. To visualize clusters

# %%
plt.figure(figsize=(16,9))
plt.title('kmeans custers')   
plt.xlabel('Number of clusters')  
plt.ylabel('sse')  
plt.scatter(X['Annual Income (k$)'],X['Spending Score (1-100)'],c=labels)
